# %%
import numpy as np
import matplotlib.pyplot as plt

# array  = np.load('new_data/J_null_continuo.npy')
array  = np.load('new_data/H_null.npy')
# Suponiendo que array tiene forma (4, N)
x = array[0]
# x = (x + 5*(x-1))//2
y_min = array[1]
y_mean = array[2]
y_std = array[3]

print(y_min[np.where(x==1750)[0][0]])

plt.figure(figsize=(8, 5))

# Curva mínima
plt.plot(x, y_min, color='green', label='Mínimo')
# Curva promedio
plt.plot(x, y_mean, color='red', label='Promedio')

# Barras de error (std)
plt.errorbar(x, y_mean, yerr=y_std,fmt='none', ecolor='black',elinewidth=1,capsize=2,alpha=0.1,label='Std')

plt.xlabel('longitud N')
plt.ylabel(r'$PE$',rotation=360)
plt.xlim(0,2000)
# plt.ylim(0.8,1.0)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 0.3703227539102001

# %%
from funciones import permutation_entropy,vocabulario_midi_centrado,random_array, angulos_alpha
import numpy as np
import matplotlib.pyplot as plt

C = []
for l in range(1,100):
    A = vocabulario_midi_centrado(k=10)
    serie = random_array(A,1750,0.4,l)
    # angulos = angulos_alpha(serie,False)
    ent = permutation_entropy(serie, m=8, tau=1) 
    C.append(ent)
plt.plot(range(1,100),C,marker='.')
plt.grid()
plt.ylim(0.0,0.7)
plt.xlabel('l')
plt.ylabel(r'$PE$',rotation=360)
# Out:
# Text(0, 0.5, '$PE$')
