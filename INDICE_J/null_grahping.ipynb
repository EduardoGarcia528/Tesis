# %%
import numpy as np
import matplotlib.pyplot as plt

# array  = np.load('new_data/J_null_continuo.npy')
array  = np.load('new_data/J_interp_null.npy')
# Suponiendo que array tiene forma (4, N)
x = array[0]
# x = (x + 5*(x-1))//2
y_min = array[1]
y_mean = array[2]
y_std = array[3]

plt.figure(figsize=(8, 5))

# Curva mínima
plt.plot(x, y_min, color='green', label='Mínimo')
# Curva promedio
plt.plot(x, y_mean, color='red', label='Promedio')

# Barras de error (std)
plt.errorbar(x, y_mean, yerr=y_std,fmt='none', ecolor='black',elinewidth=1,capsize=2,alpha=0.1,label='Std')

plt.xlabel('N fases')
plt.ylabel('J')
plt.xlim(0,2000)
# plt.ylim(0.8,1.0)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
