# %%
from music21 import converter

# Ruta de tu archivo .mxl
archivo = r"E:\mxl\1\18\QmbErPkk1PQFcFAYN8Uiz6aBMihNLDfmjfrAYAoZ7sNJFm.mxl"

# Leer la partitura
score = converter.parse(archivo)

# Mostrar la partitura
score.show()
# Out:
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
