# %%
import numpy as np
from funciones import indice_J, permutation_entropy

array = np.load("chopin1d.npy")
print(len(array))
print(indice_J(array,False), permutation_entropy(array,5))
# Out:
# 2276
# 0.9270594241408521 0.9071025010752916

# %%
import pandas as pd

df = pd.read_csv('data\metadatos_piezas.csv')

df.loc[df["Genero"] == 'Concerto\n']
# Out:
#        Compositor Fecha de nacimiento  \
# 13374      chopin                 NaN
# 13381      chopin                 NaN
# 13397      chopin                 NaN
# 13399      chopin                 NaN
# 13497      chopin                 NaN
# 13558      chopin                 NaN
# 13599      chopin                 NaN
# 13662      chopin                 NaN
# 13679      chopin                 NaN
# 13799      chopin                 NaN
# 25066  polyrhythm                 NaN
# 25075  polyrhythm                 NaN
# 25077  polyrhythm                 NaN
# 25080  polyrhythm                 NaN
# 25082  polyrhythm                 NaN
# 25106  polyrhythm                 NaN
# 25109  polyrhythm                 NaN
# 25111  polyrhythm                 NaN
# 25134  polyrhythm                 NaN
#
#                                        Titulo de la obra  \
# 13374                    Concerto e-minor, cz.3 Rondo.\n
# 13381                   Concerto e-minor, cz.2 Romance\n
# ...

# %%
a = [2,3,4,6,7,4,2,4]
a[:2] + a[4:7]
# Out:
# [2, 3, 7, 4, 2]

# %%
import numpy as np
import matplotlib.pyplot as plt

J1 = np.load("J_audio\Js_melody_repeat_C.npy")

plt.plot(range(1, len(J1) + 1), J1, label="Escala de Do")
plt.xlabel("Número de notas")
plt.ylabel("Índice J")
plt.legend()
plt.show()
